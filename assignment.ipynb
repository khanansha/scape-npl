# %%
import glob
import json
import csv
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk import sent_tokenize, word_tokenize, pos_tag
import string
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
df=pd.read_csv('C:/Users/akhan.extern/Desktop/jsondata/Reviews.csv')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# # Data Exploration

# %%
print("Summary statistics of numerical features : \n", df.describe())

print("\nTotal number of reviews: ",len(df))
print("\nTotal number of unique products: ", len(list(set(df['ProductId']))))

print("\nPercentage of reviews with neutral sentiment : {:.2f}%"\
      .format(df[df['Score']==3]["Score"].count()/len(df)*100))
print("\nPercentage of reviews with positive sentiment : {:.2f}%"\
      .format(df[df['Score']>3]["Score"].count()/len(df)*100))
print("\nPercentage of reviews with negative sentiment : {:.2f}%"\
      .format(df[df['Score']<3]["Score"].count()/len(df)*100))
# Out:
# Summary statistics of numerical features :
#                    Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count  568454.000000         568454.000000            568454.00000
# mean   284227.500000              1.743817                 2.22881
# std    164098.679298              7.636513                 8.28974
# min         1.000000              0.000000                 0.00000
# 25%    142114.250000              0.000000                 0.00000
# 50%    284227.500000              0.000000                 1.00000
# 75%    426340.750000              2.000000                 2.00000
# max    568454.000000            866.000000               923.00000
#
#                Score          Time
# count  568454.000000  5.684540e+05
# mean        4.183199  1.296257e+09
# std         1.310436  4.804331e+07
# min         1.000000  9.393408e+08
# 25%         4.000000  1.271290e+09
# 50%         5.000000  1.311120e+09
# 75%         5.000000  1.332720e+09
# ...

# %% [markdown]
# # Data Visualization

# %%
# Plot number of reviews for top 30 products
products = df["ProductId"].value_counts()
plt.figure(figsize=(12,8))
products[:30].plot(kind='bar')
plt.title("Number of Reviews for Top 30 Products")
# Out:
# Text(0.5, 1.0, 'Number of Reviews for Top 30 Products')

# %% [markdown]
# # NLP

# %%
def tokenize_words_Sents(Sent):
    return word_tokenize(Sent),sent_tokenize(Sent)
def tokenize_words(Sent):
    return word_tokenize(Sent)   
def RegExpTokenizer(Sent):
    tokenizer = RegexpTokenizer(r'\w+')
    return tokenizer.tokenize(Sent)
# Words,Sents = tokenize_words_Sents(df.loc[:, 'Summary'].tolist())
Words,Sents = tokenize_words_Sents(df.iloc[5,8])
print("Words ",Words)
print("Sents ",Sents)
# Out:
# Words  ['Great', '!', 'Just', 'as', 'good', 'as', 'the', 'expensive', 'brands', '!']
# Sents  ['Great!', 'Just as good as the expensive brands!']

# %%
from nltk.corpus import stopwords
#nltk.download('stopwords')
def Eliminate_Stop_Words(Sent):
    stop_words = set(stopwords.words("english"))
    filtered_words = []
    for w in Sent:
        if w not in stop_words:
            filtered_words.append(w)
    return stop_words,filtered_words

def Eliminate_Stop_Word(Sent):
    stop_words = set(stopwords.words("english"))
    filtered_words = []
    for w in Sent:
        if w not in stop_words:
            filtered_words.append(w)
    return filtered_words

stop_words,filtered_words = Eliminate_Stop_Words(Words)
print(stop_words)
print("------------------Words ------------------------")
print(Words)
print("------------------Words filltred---------------------")
print(filtered_words)
# Out:
# {"shouldn't", 'it', 'own', 'yours', 'down', "couldn't", 'couldn', 'which', 'themselves', 'don', 'o', 'aren', "hasn't", 'of', 'will', 'wasn', 'so', 'ma', 'too', "doesn't", "needn't", 'after', 'some', 'mustn', 'a', 'few', 'll', "haven't", 'on', 'above', 'myself', 'him', 'or', 'have', 'been', 'against', 'ourselves', 'just', 're', 'by', 'do', 'an', 'is', "don't", 'having', 'into', 'out', 'only', "mightn't", 'both', "won't", "should've", "didn't", 'she', 'up', 'does', 'about', 'my', "wasn't", 'did', 'was', 'them', 'are', 'who', 'once', "it's", 'than', 'didn', 'this', 'theirs', 'each', "mustn't", 'when', 'herself', 'y', 'as', 'if', 'hasn', 'doesn', 'wouldn', 'being', "you'd", 'm', 'can', 'other', "wouldn't", 'between', 'not', 'shouldn', 'while', 'those', 'should', 'very', "shan't", 'me', 'ain', 'most', "you'll", 'under', 'isn', 'be', 'until', 'the', 's', 'hadn', 't', 'these', 'doing', "hadn't", 'off', 'for', 've', 'to', 'mightn', 'through', 'ours', 'further', 'more', 'her', 'd', 'needn', '
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# I only consider reviews with positive sentiment (rating = 4, 5) and negative sentiment (rating = 1, 2), and drop reviews with neutral sentiment (rating 3).

# %%
# Drop missing values
df.dropna(inplace=True)
# Remove any 'neutral' ratings equal to 3
# df = df[df['Score'] != 3]
df =df.query('Score != 3 & Score != 2')
# Encode 4s and 5s as (positive sentiment) and 1s and 2s as (negative sentiment)
df['Sentiment'] = np.where(df['Score'] > 3, 'positive', 'negative')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
negative = df.loc[df['Sentiment'] == 'negative']
negative.head()
# Out:
#     Id   ProductId          UserId    ProfileName  HelpfulnessNumerator  \
# 1    2  B00813GRG4  A1D87F6ZCVE5NK         dll pa                     0
# 12  13  B0009XLVG0   A327PCT23YH90             LT                     1
# 26  27  B001GVISJM  A3RXAU2N8KV45G         lady21                     0
# 50  51  B001EO5QW8  A108P30XVUFKXY      Roberto A                     0
# 62  63  B001EO5TPM  A1E09XGZUR78C6  gary sturrock                     2
#
#     HelpfulnessDenominator  Score        Time  \
# 1                        0      1  1346976000
# 12                       1      1  1339545600
# 26                       1      1  1332633600
# 50                       7      1  1203379200
# 62                       2      1  1215302400
#
#                                  Summary  \
# 1                      Not as Advertised
# 12  My Cats Are Not Fans of the New Food
# 26                       Nasty No flavor
# 50                         Don't like it
# ...

# %%
neg=negative[negative["Summary"].str.contains('good|product')==False]
neg.head()
# Out:
#     Id   ProductId          UserId     ProfileName  HelpfulnessNumerator  \
# 1    2  B00813GRG4  A1D87F6ZCVE5NK          dll pa                     0
# 12  13  B0009XLVG0   A327PCT23YH90              LT                     1
# 26  27  B001GVISJM  A3RXAU2N8KV45G          lady21                     0
# 50  51  B001EO5QW8  A108P30XVUFKXY       Roberto A                     0
# 73  74  B0059WXJKM  A25VFHVGI4CFTP  Diana Robinson                     0
#
#     HelpfulnessDenominator  Score        Time  \
# 1                        0      1  1346976000
# 12                       1      1  1339545600
# 26                       1      1  1332633600
# 50                       7      1  1203379200
# 73                       1      1  1335744000
#
#                                  Summary  \
# 1                      Not as Advertised
# 12  My Cats Are Not Fans of the New Food
# 26                       Nasty No flavor
# 50                         Don't like it
# ...

# %%
from wordcloud import WordCloud, STOPWORDS 
comment_words = '' 
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in neg.Summary: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
positive_review = df.loc[df['Sentiment'] == 'positive']
positive_review.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
# 6   7  B006K2ZZ7K  A1SP2KVKFXXRU1                David C. Sullivan
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 2                     1                       1      4  1219017600
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
# 6                     0                       0      5  1340150400
#
#                                          Summary  \
# 0                          Good Quality Dog Food
# 2                          "Delight" says it all
# ...

# %%
from wordcloud import WordCloud, STOPWORDS 
comment_words = '' 
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in positive_review.Summary: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# # convert unix time into date time

# %%
df['date'] = pd.to_datetime(df['Time'],unit='s')
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# 5   6  B006K2ZZ7K   ADT0SRK1MGOEU                   Twoapennything
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 4                     0                       0      5  1350777600
# 5                     0                       0      4  1342051200
#
#                  Summary                                               Text  \
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df1 =df.query('year == 2011 & month == 4')
df1.head()
# Out:
#       Id   ProductId          UserId  \
# 0      1  B001E4KFG0  A3SGXH7AUHU8GW
# 40    41  B001EO5QW8   AQCY5KRO7489S
# 41    42  B001EO5QW8  A1WK4ALVZDYPUE
# 96    97  B0019CW0HE  A18AAABCIJKC5Q
# 141  142  B001GVISJW  A2YIO225BTKVPU
#
#                                           ProfileName  HelpfulnessNumerator  \
# 0                                          delmartian                     1
# 40                                            Garrett                     0
# 41                           Dick Baldwin "christobe"                     0
# 96                                            Rhiever                     0
# 141  Angel_Boy "Treat the people around you the wa...                     0
#
#      HelpfulnessDenominator  Score        Time  \
# 0                         1      5  1303862400
# 40                        0      5  1303430400
# 41                        0      5  1302134400
# 96                        0      5  1303776000
# ...

# %%
df.to_csv('C:/Users/akhan.extern/Desktop/modify_review.csv')
